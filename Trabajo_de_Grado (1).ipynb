# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

# ---------- CONTENIDO ----------
bienvenida = """
<h2>Leer el Cálculo</h2>
<p>
Esta aplicación educativa invita a comprender el cálculo desde la lectura y la escritura.
Inspirada en <i>La lectura del Cálculo</i> de Bernardo Mayorga, propone pensar conceptos
como el límite desde el lenguaje, el sentido y la reflexión matemática.
</p>
"""

seccion1 = """
<h3> Cálculo y Lenguaje</h3>
<p>
El cálculo no solo se resuelve: también se interpreta. Las palabras, metáforas y
estructuras narrativas permiten comprender ideas como continuidad, cambio y variación.
</p>
"""

seccion2 = """
<h3> Escritura Matemática</h3>
<p>
Escribir matemáticas es pensar matemáticamente. La escritura permite organizar ideas,
formular argumentos y construir significado más allá del símbolo.
</p>
"""

# ---------- FUNCIONES ----------
def mostrar(texto):
    clear_output()
    display(widgets.HTML(texto))
    display(menu)

# ---------- BOTONES ----------
btn_inicio = widgets.Button(description="Inicio")
btn_lenguaje = widgets.Button(description="Cálculo y Lenguaje")
btn_escritura = widgets.Button(description="Escritura Matemática")

btn_inicio.on_click(lambda x: mostrar(bienvenida))
btn_lenguaje.on_click(lambda x: mostrar(seccion1))
btn_escritura.on_click(lambda x: mostrar(seccion2))

menu = widgets.HBox([btn_inicio, btn_lenguaje, btn_escritura])

# ---------- MOSTRAR ----------
mostrar(bienvenida)
# Out:
# HTML(value='\n<h2>Leer el Cálculo</h2>\n<p>\nEsta aplicación educativa invita a comprender el cálculo desde la…
# ...
